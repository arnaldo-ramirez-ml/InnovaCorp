# %% [markdown]
# ## **InnovaCorp**
# # Bibliotecas

# %%
import sqlite3
import pandas as pd
import os

# %% [markdown]
# # Descarga de la base de datos
#
# ---
#
#
# Tamaño del archivo: 315392 bytes

# %%
# Descarga del dataset desde GitHub
URL_DATASET = "https://github.com/arnaldo-ramirez-ml/InnovaCorp/releases/download/1.0/InnovaCorp.db"
# !wget -q -O InnovaCorp.db {URL_DATASET}

# Verificación de descarga
print("Tamaño del archivo:", os.path.getsize("InnovaCorp.db"), "bytes")
# Out:
# Tamaño del archivo: 315392 bytes

# %% [markdown]
# # Conexión a la base de datos

# %%
con = sqlite3.connect("/content/InnovaCorp.db")

consulta_sql = "SELECT * FROM EMPLEADOS"
df = pd.read_sql(consulta_sql, con)
df.shape
# Out:
# (2014, 13)
